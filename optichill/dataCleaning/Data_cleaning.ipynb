# %% [markdown]
# # Chiller plant data cleaning
#
# The purpose of this notebook is to outline methods for determining which chiller data sets should be used in the regression analysis.
#
# Components:
#  - remove data points that contain NaN values
#  - remove data points where OptimumControl = 0
#  - remove data points with sensor alarms

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import glob
import os
import bas_filter

# %% [markdown]
# ## Reading Data into Jupyter

# %%
df = pd.read_csv('../../Capstone/Files/Plt1 h 2017-09.csv')
key = pd.read_excel('../../Capstone/Files/Plt1 Points List.xlsx')

# %% [markdown]
# ### Test to drop NaN values from data

# %%
df.dropna()
# Out:
#                     timestamp  CH3LoadDisp  CH3PctLoad  CH4LoadDisp  \
# 60   2017-09-03T12:00:00.000Z     0.000000     0.00000    87.101169
# 61   2017-09-03T13:00:00.000Z     0.000000     0.00000    61.628025
# 62   2017-09-03T14:00:00.000Z     0.000000     0.00000    65.271903
# 63   2017-09-03T15:00:00.000Z     0.000000     0.00000    62.073736
# 66   2017-09-03T18:00:00.000Z     0.000000     0.00000    66.073464
# 67   2017-09-03T19:00:00.000Z     0.000000     0.00000    64.536953
# 68   2017-09-03T20:00:00.000Z     0.000000     0.00000    60.918676
# 69   2017-09-03T21:00:00.000Z     0.000000     0.00000    57.567634
# 70   2017-09-03T22:00:00.000Z     0.000000     0.00000    40.959836
# 71   2017-09-03T23:00:00.000Z     0.000000     0.00000     0.000000
# 493  2017-09-21T13:00:00.000Z    53.827729    53.83398    23.577009
#
#      CH4PctLoad  CH5LoadDisp  CH5PctLoad      CHkW%     CHTON%  \
# 60    87.101168     0.982292    0.982292  71.551070  86.750559
# 61    61.649601    32.699242   32.699242  28.800355  46.600451
# 62    65.271902    34.757415   34.667396  31.222250  49.421877
# 63    60.817505    35.873339   35.490721  31.827724  50.010946
# 66    66.073463    37.944247   37.944247  34.189070  52.350163
# 67    64.555182    36.308257   36.305479  32.816663  50.486619
# 68    60.918676    33.823301   33.823301  30.818600  47.683522
# 69    57.580631    32.202592   32.206610  29.244369  44.708515
# 70    41.008944    42.549615   42.540327  31.184866  50.812883
# 71     0.000000    78.306298   77.869101  50.595238  78.069033
# 493   23.577009    35.312489   35.312489  30.467763  47.574750
#
#      PercentAnnualSavings     ...      CH5SURGE  LOOPREQ  RUNCHLR3  RUNCHLR4  \
# 60               0.000124     ...           0.0      1.0  0.000000  1.000000
# 61               0.000184     ...           0.0      1.0  0.000000  1.000000
# 62               0.000195     ...           0.0      1.0  0.000000  1.000000
# 63               0.000182     ...           0.0      1.0  0.166667  1.000000
# 66               0.000190     ...           0.0      1.0  0.000000  1.000000
# 67               0.000187     ...           0.0      1.0  0.000000  1.000000
# 68               0.000179     ...           0.0      1.0  0.000000  1.000000
# 69               0.000156     ...           0.0      1.0  0.000000  1.000000
# 70               0.000141     ...           0.0      1.0  0.000000  0.666667
# 71               0.000098     ...           0.0      1.0  0.000000  0.000000
# 493              0.000200     ...           0.0      1.0  0.916667  1.000000
#
#      RUNCHLR5  CH3SURGECNT  CH4SURGECNT  CH5SURGECNT  CLGMODE  StationSTG
# 60   0.166667         13.0          0.0          0.0      0.0    1.166667
# 61   1.000000         13.0          0.0          0.0      0.0    2.000000
# 62   1.000000         13.0          0.0          0.0      0.0    2.000000
# 63   1.000000         13.0          0.0          0.0      0.0    2.000000
# 66   1.000000         13.0          0.0          0.0      0.0    2.000000
# 67   1.000000         13.0          0.0          0.0      0.0    2.000000
# 68   1.000000         13.0          0.0          0.0      0.0    2.000000
# 69   1.000000         13.0          0.0          0.0      0.0    2.000000
# 70   1.000000         13.0          0.0          0.0      0.0    1.583333
# 71   1.000000         13.0          0.0          0.0      0.0    1.000000
# 493  1.000000         13.0          0.0          0.0      0.0    2.500000
#
# [11 rows x 414 columns]

# %% [markdown]
# Result: only 11 data points of the dataframe contained no blank cells. This can be refined by extracting the BAS parameters.

# %% [markdown]
# ## BAS Extraction

# %%
# collects DataPointNames from the points list spreadsheet that are BAS point types
key_bas = key.loc[key['PointType'].str.contains("BAS")==True,'DataPointName']

#converts pandas series to a list for future use
val = key_bas.values.T.tolist()

#removes DataPointNames that containt the prefix CHWV
vals = [x for x in val if not x.startswith('CHWV')]

#tests whether all values from the point list spreadsheet are column headings of the dataset
for x in vals:
    if x not in df.columns:
        #prints and removes any string not found in the data
        print(x)
        vals.remove(x)
        
#expresses data using columns specified by the vals list
bas = df[vals+['OptimumControl', 'kW/Ton']]
print('Original data contains '+str(df.shape[0])+' points and '+str(df.shape[1])+ ' dimensions.')
print('Filtered data contains '+str(bas.dropna().shape[0])+' points and '+str(bas.dropna().shape[1])+ ' dimensions.')
# Out:
# CommunicationFailure_COV
# Original data contains 1465 points and 414 dimensions.
# Filtered data contains 1432 points and 66 dimensions.

# %% [markdown]
# This result tells us that very few of the BAS points are missing entries. The data can be further filtered with statements exemplified below.

# %%
bas[bas['OptimumControl'] == 1]
# Out:
#       CDWVLV  CDWVLV2        CHkW     CHWDP2      CHWFLO      CHWRT  \
# 0        1.0      1.0  107.750000  10.749720  671.000000  55.882812
# 1        1.0      1.0  101.333333  10.560215  674.500000  55.416667
# 2        1.0      1.0  121.500000   6.449532  621.125000  56.752604
# 3        1.0      1.0  116.333333   8.820532  592.291667  55.851562
# 4        1.0      1.0  116.833333   8.449738  593.541667  56.518229
# 5        1.0      1.0  116.416667   8.006648  606.541667  56.609375
# 6        1.0      1.0  105.416667   9.884717  573.583333  55.822917
# 7        1.0      1.0  101.500000  10.232507  569.750000  56.296875
# 8        1.0      1.0  115.083333   9.928898  620.166667  55.500000
# 9        1.0      1.0  123.250000   7.364924  647.666667  55.729167
# 10       1.0      1.0  139.583333   5.985264  663.958333  56.179688
# 11       1.0      1.0  132.583333  12.098344  791.541667  54.828125
# 12       1.0      1.0  129.833333  12.028969  757.291667  55.479167
# 13       1.0      1.0  140.250000  11.926001  773.708333  55.848958
# 16         1.0             1.0  0.486711
# 17         1.0             1.0  0.487684
# 18         1.0             1.0  0.481418
# 19         1.0             1.0  0.460678
# 20         1.0             1.0  0.442666
# 21         1.0             1.0  0.459837
# 22         1.0             1.0  0.478758
# 23         1.0             1.0  0.553762
# 24         1.0             1.0  0.563146
# 25         1.0             1.0  0.538759
# 26         1.0             1.0  0.543236
# 27         1.0             1.0  0.521034
# 28         1.0             1.0  0.510343
# 29         1.0             1.0  0.508567
# ...        ...             ...       ...
# 1434       1.0             1.0  0.374181
# 1435       1.0             1.0  0.359031
# 1436       1.0             1.0  0.335354
# 1437       1.0             1.0  0.343418
# 1438       1.0             1.0  0.351188
# 1439       1.0             1.0  0.340609
# 1440       1.0             1.0  0.333973
# 1441       1.0             1.0  0.319551
# 1442       1.0             1.0  0.323530
# 1443       1.0             1.0  0.313885
# 1444       1.0             1.0  0.313849
# 1445       1.0             1.0  0.312068
# 1446       1.0             1.0  0.304753
# 1447       1.0             1.0  0.301075
# 1448       1.0             1.0  0.305581
# 1449       1.0             1.0  0.322107
# 1450       1.0             1.0  0.330975
# 1451       1.0             1.0  0.352704
# 1452       1.0             1.0  0.388052
# 1453       1.0             1.0  0.418291
# 1454       1.0             1.0  0.428052
# 1455       1.0             1.0  0.441311
# 1456       1.0             1.0  0.439576
# 1457       1.0             1.0  0.422867
# 1458       1.0             1.0  0.436714
# 1459       1.0             1.0  0.422729
# 1460       1.0             1.0  0.414836
# 1461       1.0             1.0  0.401938
# 1462       1.0             1.0  0.379008
# 1463       1.0             1.0  0.366591
#
# [1464 rows x 66 columns]

# %% [markdown]
# ## Function Workup

# %%
def data_import(dat_folder, string, keys):
    
    dat_list = [f for f in glob.glob(os.path.join(dat_folder, string + '*'))]
    print(dat_list)
    
    df = pd.DataFrame()
    for lst in dat_list:
        df_add = pd.read_csv(lst)
        df = pd.concat([df, df_add], ignore_index=True)
    key = pd.read_excel(keys)
    
    return df, key

# %%
df, key = data_import('../../Capstone/files', 'Plt1 h', '../../Capstone/files/Plt1 Points List.xlsx')
# Out:
# ['../../Capstone/files\\Plt1 h 2016-11.csv', '../../Capstone/files\\Plt1 h 2017-01.csv', '../../Capstone/files\\Plt1 h 2017-03.csv', '../../Capstone/files\\Plt1 h 2017-05.csv', '../../Capstone/files\\Plt1 h 2017-07.csv', '../../Capstone/files\\Plt1 h 2017-09.csv']

# %%
def data_BAS(df, key):
    # collects DataPointNames from the points list spreadsheet that are BAS point types
    key_bas = key.loc[key['PointType'].str.contains("BAS")==True,'DataPointName']

    #converts pandas series to a list for future use
    val = key_bas.values.T.tolist()

    #removes DataPointNames that containt the prefix CHWV
    vals = [x for x in val if not x.startswith('CHWV')]

    #tests whether all values from the point list spreadsheet are column headings of the dataset
    for x in vals:
        if x not in df.columns:
            #prints and removes any string not found in the data
            print(x)
            vals.remove(x)
        
    #expresses data using columns specified by the vals list
    bas = df[vals+['OptimumControl', 'kW/Ton']]
    
    print('Original data contains '+str(df.shape[0])+' points and '+str(df.shape[1])+ ' dimensions.')
    print('Filtered data contains '+str(bas.dropna().shape[0])+' points and '+str(bas.dropna().shape[1])+ ' dimensions.')
    return bas.dropna()

# %%
bas = data_BAS(df, key)
bas.shape
# Out:
# CommunicationFailure_COV
# Original data contains 8516 points and 414 dimensions.
# Filtered data contains 8115 points and 66 dimensions.
# (8115, 66)

# %%
key_alarm = key[key['Units'].str.contains("Normal/Alarm")==True]
key_alarm_BAS = key_alarm.loc[key['PointType'].str.contains("BAS")==True, 'DataPointName']
print(key_alarm_BAS)
# Out:
# 37    CommunicationFailure
# 39              CTTR_ALARM
# 54            PCHWP3Failed
# 60            PCHWP4Failed
# 66            PCHWP5Failed
# 72            SCHWP3Failed
# 78            SCHWP4Failed
# 84            SCHWP5Failed
# Name: DataPointName, dtype: object

# %%
for alm in key_alarm_BAS:
    bas = bas[bas[alm] == 0]
bas = bas[bas['OptimumControl'] == 1]

# %%
bas.shape
# Out:
# (7952, 66)

# %%
def alarm_filter(bas, key):
    key_alarm = key[key['Units'].str.contains("Normal/Alarm")==True]
    key_alarm_BAS = key_alarm.loc[key['PointType'].str.contains("BAS")==True, 'DataPointName']
    
    for alm in key_alarm_BAS:
        bas = bas[bas[alm] == 0]
    bas = bas[bas['OptimumControl'] == 1]
    return bas

# %%
bas1 = alarm_filter(bas, key)
bas1.shape
# Out:
# (7952, 66)

# %%
bas1[bas1['HX1CDWVLV'] < 1].shape
# Out:
# (7952, 66)

# %% [markdown]
# ## Function .py Testing

# %%
df, key = bas_filter.data_import('../../Capstone/files', 'Plt1 h', '../../Capstone/files/Plt1 Points List.xlsx')
bas = bas_filter.data_BAS(df, key)
bas1 = bas_filter.alarm_filter(bas, key)
bas1.shape
# Out:
# ['../../Capstone/files\\Plt1 h 2016-11.csv', '../../Capstone/files\\Plt1 h 2017-01.csv', '../../Capstone/files\\Plt1 h 2017-03.csv', '../../Capstone/files\\Plt1 h 2017-05.csv', '../../Capstone/files\\Plt1 h 2017-07.csv', '../../Capstone/files\\Plt1 h 2017-09.csv']
# CommunicationFailure_COV
# Original data contains 8516 points and 414 dimensions.
# Filtered data contains 8115 points and 66 dimensions.
# (7952, 66)

# %%
df, key = bas_filter.import_and_filter('../../Capstone/files', 'Plt1 h', '../../Capstone/files/Plt1 Points List.xlsx')
df.shape
# Out:
# ['../../Capstone/files\\Plt1 h 2016-11.csv', '../../Capstone/files\\Plt1 h 2017-01.csv', '../../Capstone/files\\Plt1 h 2017-03.csv', '../../Capstone/files\\Plt1 h 2017-05.csv', '../../Capstone/files\\Plt1 h 2017-07.csv', '../../Capstone/files\\Plt1 h 2017-09.csv']
# CommunicationFailure_COV
# Original data contains 8516 points and 414 dimensions.
# Filtered data contains 8115 points and 66 dimensions.
# (7952, 66)
